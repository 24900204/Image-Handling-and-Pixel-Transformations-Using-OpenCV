# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("Eagle_in_Flight.jpg" )

# %%
img.size
# Out:
# 1382400

# %%
img.shape
# Out:
# (600, 768, 3)

# %%
plt.imshow(img[:,:,::-1])
plt.axis('on')
plt.show()
